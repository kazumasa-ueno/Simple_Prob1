# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.loadtxt("./output/ercheck2.txt")
data = data.reshape(10,66,66)
for i in range(10):
	plt.contourf(data[i])
	plt.colorbar()
	plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# セル2 を /Users/uenokazumasa/書類/4a_Research/Simple_Prob1/multigrid/plot.ipynb in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/uenokazumasa/%E6%9B%B8%E9%A1%9E/4a_Research/Simple_Prob1/multigrid/plot.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> data = np.loadtxt("./output/ercheck2.txt")
# ----> <a href='vscode-notebook-cell:/Users/uenokazumasa/%E6%9B%B8%E9%A1%9E/4a_Research/Simple_Prob1/multigrid/plot.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a> data = data.reshape(10,130,130)
#       <a href='vscode-notebook-cell:/Users/uenokazumasa/%E6%9B%B8%E9%A1%9E/4a_Research/Simple_Prob1/multigrid/plot.ipynb#W4sZmlsZQ%3D%3D?line=2'>3</a> for i in range(10):
#       <a href='vscode-notebook-cell:/Users/uenokazumasa/%E6%9B%B8%E9%A1%9E/4a_Research/Simple_Prob1/multigrid/plot.ipynb#W4sZmlsZQ%3D%3D?line=3'>4</a> 	plt.contourf(data[i])
#
# ValueError: cannot reshape array of size 43560 into shape (10,130,130)

# %%
x = np.array(128)
data = np.loadtxt("./output/output.txt")
print(data.max(axis=0))
data = data.reshape(130,130)
plt.contour(data)
# Out:
# 4.1528682887560375

# %%
data1 = np.loadtxt("./output/timeseries.txt")
data2 = np.loadtxt("./output/timeseries2.txt")
fig,ax = plt.subplots()
ax.set_yscale("log")
# plt.xlim([0,300])
ax.plot(data1,label="pre=10 twogrid")
ax.plot(data2,label="singlegrid")
ax.legend()
plt.show()
